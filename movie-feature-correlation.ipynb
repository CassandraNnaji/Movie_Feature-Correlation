# %%
# Load Libraries

import pandas as pd
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

import seaborn as sns 

# %matplotlib inline
matplotlib.rcParams['figure.figsize']=(12,8) #Adjusts the configuration of the plots

# %%
# Load the dataset

df = pd.read_csv('/kaggle/input/movies/movies.csv')

# %%
# Take a look at the dataset 
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Check out some info on the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
# Check for missing values

df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
# Make a copy of the dataset
df1 = df.copy()
df1.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# For this specific project, drop the null values 
df1 = df1.dropna(axis=0)
df1.tail(10)
# Out:
#                       name     rating      genre  year  \
# 7604                Mine 9  Not Rated      Drama  2019
# 7616       High on the Hog          R     Action  2019
# 7643                 Tenet      PG-13     Action  2020
# 7645         Birds of Prey          R     Action  2020
# 7646     The Invisible Man          R      Drama  2020
# 7648     Bad Boys for Life          R     Action  2020
# 7649    Sonic the Hedgehog         PG     Action  2020
# 7650              Dolittle         PG  Adventure  2020
# 7651  The Call of the Wild         PG  Adventure  2020
# 7652     The Eight Hundred  Not Rated     Action  2020
#
#                                released  score     votes           director  \
# 7604              May 19, 2020 (Poland)    6.4    4400.0      Eddie Mensore
# 7616     April 16, 2019 (United States)    3.5     195.0          Tony Wash
# 7643  September 3, 2020 (United States)    7.4  387000.0  Christopher Nolan
# ...

# %%
# Check colunm datatypes
df1.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Change datatype of columns to fix number value 

df1['budget'] = df1['budget'].astype('int64')
df1['gross'] = df1['gross'].astype('int64')

# %%
df1.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %%
# Removing the string within the paratheses

# Change the dtype to a string
df1['released']=df1['released'].astype('str')

# We are removing the paratheses and everything in it and replacing it with a space. then getting rid of the whitespace
df1['released']=df1['released'].str.replace(r"\s*\([^()]*\)", "", regex=True).str.strip()

df1['released'].head(5)
# Out:
# 0    June 13, 1980
# 1     July 2, 1980
# 2    June 20, 1980
# 3     July 2, 1980
# 4    July 25, 1980
# Name: released, dtype: object

# %%
# Extract the year from the released column and enter it into the new colunm 
df1['YearCorrect']= df1['released'].str[-4:]

df1['YearCorrect'].head(5)
# Out:
# 0    1980
# 1    1980
# 2    1980
# 3    1980
# 4    1980
# Name: YearCorrect, dtype: object

# %%
# Sort the data by the gross

df1.sort_values(by='gross', inplace=False, ascending=False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                released  score      votes             director  \
# ...

# %%
# To be able to see the whole dataset
pd.set_option('display.max_rows',None)

df1

# %%
# Check for duplicates

df1.duplicated().sum()

# %%
# Create Scatterplot with budget vs gross

plt.scatter(x='budget', y='gross', data=df1)
plt.title('Budget vs Gross Eaarnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')
plt.show()

# %%
# Plot budget vs gross using seaborn regplot

sns.regplot(x='budget', y='gross', data=df1, scatter_kws={"color": "red"}, line_kws={"color":"blue"})
plt.title('Budget vs Gross Eaarnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')

# %%
# Look at correlation between numerical variables 

df1.corr(method='pearson' ,numeric_only=True) # pearson(default), kendall, spearman

# %% [markdown]
# There is a high correlation between budeget and gross

# %%
# Create a heatmap

correlation_matrix =df1.corr(method='pearson' ,numeric_only=True)

sns.heatmap(correlation_matrix, annot=True, cmap='Reds')
plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
# Out:
# Text(120.72222222222221, 0.5, 'Movie Features')

# %%
# Make categorical variables numeric

df_numeric = df1

for col_name in df_numeric.columns:
    if(df_numeric[col_name].dtype == 'object'):
        df_numeric[col_name]=df_numeric[col_name].astype('category')
        df_numeric[col_name]=df_numeric[col_name].cat.codes
        
df_numeric.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  4692       6      6  1980      1239    8.4   927000.0      1795    2832
# 1  3929       6      1  1980      1065    5.8    65000.0      1578    1158
# 2  3641       4      0  1980      1288    8.7  1200000.0       757    1818
# 3   204       4      4  1980      1065    7.7   221000.0       889    1413
# 4   732       6      4  1980      1108    7.3   108000.0       719     351
#
#    star  country    budget      gross  company  runtime  YearCorrect
# 0   699       46  19000000   46998772     1426    146.0            0
# 1   214       47   4500000   58853106      452    104.0            0
# 2  1157       47  18000000  538375067      945    124.0            0
# 3  1474       47   3500000   83453539     1108     88.0            0
# 4   271       47   6000000   39846344     1083     98.0            0

# %%
# Check the data types
df_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5421 entries, 0 to 7652
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         5421 non-null   int16
#  1   rating       5421 non-null   int8
#  2   genre        5421 non-null   int8
#  3   year         5421 non-null   int64
#  4   released     5421 non-null   int16
#  5   score        5421 non-null   float64
#  6   votes        5421 non-null   float64
#  7   director     5421 non-null   int16
#  8   writer       5421 non-null   int16
#  9   star         5421 non-null   int16
#  10  country      5421 non-null   int8
#  11  budget       5421 non-null   int64
#  12  gross        5421 non-null   int64
#  13  company      5421 non-null   int16
#  14  runtime      5421 non-null   float64
#  15  YearCorrect  5421 non-null   int8
# dtypes: float64(3), int16(6), int64(3), int8(4)
# memory usage: 381.2 KB

# %%
# Create a heatmap on the new dataframe 'df_numeric'

correlation_matrix =df_numeric.corr(method='pearson' ,numeric_only=True)

sns.heatmap(correlation_matrix, annot=True, cmap='Reds')
plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
# Out:
# Text(120.72222222222221, 0.5, 'Movie Features')

# %%
# Create a correlation table where we can see which variable are highly correlated easily

corr_matrix = df_numeric.corr()
corr_pairs = corr_matrix.unstack()
corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.029234
#              genre          0.010996
#              year           0.025542
#              released      -0.006155
#              score          0.014450
#              votes          0.012615
#              director       0.015246
#              writer         0.012880
#              star          -0.006882
#              country       -0.025490
#              budget         0.023392
#              gross          0.005639
#              company        0.021697
#              runtime        0.010850
#              YearCorrect    0.025542
# rating       name          -0.029234
#              rating         1.000000
#              genre          0.147796
#              year           0.019499
#              released       0.017349
#              score          0.065983
#              votes          0.006031
#              director       0.014656
#              writer        -0.003149
# ...

# %%
# Sorting the pairs in a descending order 

sorted_pairs = corr_pairs.sort_values(ascending=False)
sorted_pairs
# Out:
# name         name           1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# YearCorrect  YearCorrect    1.000000
#              year           0.998726
# year         YearCorrect    0.998726
# budget       gross          0.740247
# gross        budget         0.740247
#              votes          0.614751
# votes        gross          0.614751
# score        votes          0.474256
# votes        score          0.474256
# budget       votes          0.439675
# ...

# %%
# Look at the pair with high correlations 

high_corr = sorted_pairs[(sorted_pairs) > 0.5]

high_corr
# Out:
# name         name           1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# YearCorrect  YearCorrect    1.000000
#              year           0.998726
# year         YearCorrect    0.998726
# budget       gross          0.740247
# gross        budget         0.740247
#              votes          0.614751
# votes        gross          0.614751
# dtype: float64

# %% [markdown]
# We see that gross and budeget have a high correlation (0.740247)and votes and gross have a high correlation (0.614751)
